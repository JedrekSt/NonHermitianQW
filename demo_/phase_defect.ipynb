# %%
import sys
import os

sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("NonHermitianQW"))))

# %%
import numpy as np
from matplotlib import pyplot as plt
from numpy import pi
from operators import op
from numpy.linalg import eig
from scipy.linalg import expm
from rabbit_2 import rabbit_wout_def,rabbit_trap

# %%
# %matplotlib inline

dim = 50
steps = 100
coin_dict = {
    "th" : np.pi/4
}
init_state_dict = {
    "x0" : dim // 2 
}
rabbit_dict = {
    "y_pos" : [dim//2 - 3 , dim//2 + 3],
    "ps" : -np.pi/2
}

model = rabbit_wout_def(dim,coin_dict,rabbit_dict,init_state_dict)
fig,ax = model.Get_evolution_with_plot(steps,5,5)
plt.show()

# %%
# %matplotlib inline

dim = 50
steps = 100
coin_dict = {
    "th" : np.pi/4
}
init_state_dict = {
    "x0" : dim // 3 
}
rabbit_dict = {
    "y_pos" : [dim//2 - 3 , dim//2 + 3],
    "ps" : -np.pi/2
}

model = rabbit_wout_def(dim,coin_dict,rabbit_dict,init_state_dict)
fig,ax = model.Get_evolution_with_plot(steps,5,5)
plt.show()

# %%
# %matplotlib inline

model.Get_eigen_vectors_with_plot()
plt.show()

# %% [markdown]
# <h1>Particle trap</h1>

# %%
# %matplotlib inline

dim = 51
steps = 100
coin_dict = {
    "th" : np.pi/4
}
init_state_dict = {
    "x0" : dim // 3 
}
rabbit_dict = {
    "y_pos" : [dim//2 - 3 , dim//2 + 3],
    "ps" : -np.pi/2
}

model = rabbit_trap(dim,coin_dict,rabbit_dict,init_state_dict)
fig,ax = model.Get_evolution_with_plot(steps,5,5)
plt.show()
